# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Store JSON into DataFrame
json_file = "../Resource/yelp_academic_dataset_business.json"

import json
data = []
with open(json_file, errors='ignore') as f:
    for line in f:
        data.append(json.loads(line))
        
business_df = pd.DataFrame(data)
business_df.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# 3                      Insurance, Financial Services     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
#
#     longitude                             name postal_code  review_count  \
# 0 -112.018481       Arizona Biltmore Golf Club       85016             5
# 1  -79.652289       Emerald Chinese Restaurant     L5R 3E7           128
# 2  -80.859132      Musashi Japanese Restaurant       28210           170
# 3 -112.395596  Farmers Insurance - Paul Lorenz       85338             3
# 4  -80.887223              Queen City Plumbing       28217             4
#
#    stars state
# 0    3.0    AZ
# 1    2.5    ON
# 2    4.0    NC
# 3    5.0    AZ
# 4    4.0    NC

# %%
# get important columns to transform
new_business_df = business_df[['business_id', 'name', 'categories', 'is_open', 'city', 'state', 'review_count', 'stars']].copy()
new_business_df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                                           categories  is_open         city  \
# 0                                  Golf, Active Life        0      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...        1  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese        1    Charlotte
# 3                      Insurance, Financial Services        1     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...        1    Charlotte
#
#   state  review_count  stars
# 0    AZ             5    3.0
# 1    ON           128    2.5
# 2    NC           170    4.0
# 3    AZ             3    5.0
# 4    NC             4    4.0

# %%
# Filter all the open restaurants
open_restaurants = new_business_df[(new_business_df.is_open==1) & (new_business_df["categories"].str.contains("Restaurant"))]
open_restaurants.head()
# Out:
#                business_id                         name  \
# 1   QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant
# 2   gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant
# 11  1Dfx3zM-rW4n-31KeC8sJg                    Taco Bell
# 13  fweCYi8FmbJXHCqLnwuk8w                Marco's Pizza
# 23  1RHY4K3BD22FK7Cfftn8Mg               Marathon Diner
#
#                                            categories  is_open  \
# 1   Specialty Food, Restaurants, Dim Sum, Imported...        1
# 2                   Sushi Bars, Restaurants, Japanese        1
# 11  Restaurants, Breakfast & Brunch, Mexican, Taco...        1
# 13         Italian, Restaurants, Pizza, Chicken Wings        1
# 23  Sandwiches, Salad, Restaurants, Burgers, Comfo...        1
#
#                   city state  review_count  stars
# 1          Mississauga    ON           128    2.5
# 2            Charlotte    NC           170    4.0
# 11             Phoenix    AZ            18    3.0
# 13  Mentor-on-the-Lake    OH            16    4.0
# 23          Pittsburgh    PA            35    4.0

# %%
# Prepare the DF to be inserted into database by choosing right columns and renaming them
df = open_restaurants[['business_id', 'name', 'city', 'state', 'review_count', 'stars']].copy()
df.rename(columns = {'name':'business_name'}, inplace = True)
df.head()
# Out:
#                business_id                business_name                city  \
# 1   QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant         Mississauga
# 2   gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant           Charlotte
# 11  1Dfx3zM-rW4n-31KeC8sJg                    Taco Bell             Phoenix
# 13  fweCYi8FmbJXHCqLnwuk8w                Marco's Pizza  Mentor-on-the-Lake
# 23  1RHY4K3BD22FK7Cfftn8Mg               Marathon Diner          Pittsburgh
#
#    state  review_count  stars
# 1     ON           128    2.5
# 2     NC           170    4.0
# 11    AZ            18    3.0
# 13    OH            16    4.0
# 23    PA            35    4.0

# %%
# Connect to Postgres DB
rds_connection_string = "postgres:password@localhost:5432/yelp_data"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['business_info']

# %%
# Write DataFrame to the database
df.to_sql(name='business_info', con=engine, if_exists='append', index=False)

# %%
# Query the data from the database table
pd.read_sql_query('select * from business_info', con=engine).head()
# Out:
#               business_id                business_name                city  \
# 0  QXAEGFB4oINsVuTFxEYKFQ   Emerald Chinese Restaurant         Mississauga
# 1  gnKjwL_1w79qoiV3IC_xQQ  Musashi Japanese Restaurant           Charlotte
# 2  1Dfx3zM-rW4n-31KeC8sJg                    Taco Bell             Phoenix
# 3  fweCYi8FmbJXHCqLnwuk8w                Marco's Pizza  Mentor-on-the-Lake
# 4  1RHY4K3BD22FK7Cfftn8Mg               Marathon Diner          Pittsburgh
#
#   state  review_count  stars
# 0    ON           128    2.5
# 1    NC           170    4.0
# 2    AZ            18    3.0
# 3    OH            16    4.0
# 4    PA            35    4.0
